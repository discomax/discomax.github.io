# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import csv
from pprint import pprint

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 589

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Create empty lists to hold the retrieved data

# test_cities is a small list of cities used for testing the code
test_cities = ["charlotte", "sydney", "xyz", "cairo"]

city_name = []
city_id = []
date = []
lat = []
max_temp = []
humid = []
wind = []
clouds = []

# create url for api calls
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
format_url = f"{url}appid={api_key}&units={units}&q="

# make the requests and load the requested data into lists
count = 0
for c in cities:
    count += 1
    query_url = f"{format_url}{c}"
    #response = requests.get(query_url).json()
    try:
        response = requests.get(query_url).json()
        city_name.append(response['name'])
        city_id.append(response['id'])
        lat.append(response['coord']['lat'])
        max_temp.append(response['main']['temp_max'])
        humid.append(response['main']['humidity'])
        wind.append(response['wind']['speed'])
        clouds.append(response['clouds']['all'])
        date.append(response['dt'])
    except:
        print('City not found. Skipping......')
    #pprint(response)
    print(f'Processing record {count} | {c}')
    print(f'{query_url + c}')
# Out:
# Processing record 1 | ancud
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=ancudancud
# City not found. Skipping......
# Processing record 2 | skiros
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=skirosskiros
# Processing record 3 | atambua
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=atambuaatambua
# Processing record 4 | hobart
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=hobarthobart
# Processing record 5 | albany
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=albanyalbany
# Processing record 6 | rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=rikitearikitea
# Processing record 7 | heishan
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=heishanheishan
# Processing record 8 | busselton
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=busseltonbusselton
# Processing record 9 | araouane
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=araouanearaouane
# Processing record 10 | college
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=collegecollege
# Processing record 11 | gubkinskiy
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=gubkinskiygubkinskiy
# Processing record 12 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=hithadhoohithadhoo
# Processing record 13 | kapaa
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=kapaakapaa
# Processing record 14 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=carnarvoncarnarvon
# Processing record 15 | vitina
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=vitinavitina
# City not found. Skipping......
# Processing record 16 | tsihombe
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=tsihombetsihombe
# Processing record 17 | mataura
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=matauramataura
# City not found. Skipping......
# Processing record 18 | tumannyy
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=tumannyytumannyy
# Processing record 19 | lamar
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=lamarlamar
# Processing record 20 | merauke
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=meraukemerauke
# Processing record 21 | bluff
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=bluffbluff
# Processing record 22 | escanaba
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=escanabaescanaba
# Processing record 23 | airai
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=airaiairai
# Processing record 24 | port hardy
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=port hardyport hardy
# Processing record 25 | tela
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=telatela
# Processing record 26 | blagoyevo
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=blagoyevoblagoyevo
# Processing record 27 | kollam
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=kollamkollam
# Processing record 28 | sitka
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=sitkasitka
# Processing record 29 | jining
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=jiningjining
# Processing record 30 | blackwater
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=blackwaterblackwater
# Processing record 31 | mehamn
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=mehamnmehamn
# Processing record 32 | hilo
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=hilohilo
# Processing record 33 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=kaitangatakaitangata
# Processing record 34 | coihueco
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=coihuecocoihueco
# Processing record 35 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=mahebourgmahebourg
# Processing record 36 | atuona
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=atuonaatuona
# Processing record 37 | manakara
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=manakaramanakara
# Processing record 38 | kudahuvadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=kudahuvadhookudahuvadhoo
# Processing record 39 | torbay
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=torbaytorbay
# Processing record 40 | correntina
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=correntinacorrentina
# Processing record 41 | butaritari
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=butaritaributaritari
# Processing record 42 | cooma
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=coomacooma
# Processing record 43 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=bambous virieuxbambous virieux
# Processing record 44 | port alfred
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=port alfredport alfred
# Processing record 45 | bethel
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=bethelbethel
# Processing record 46 | okhotsk
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=okhotskokhotsk
# City not found. Skipping......
# Processing record 47 | saleaula
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=saleaulasaleaula
# Processing record 48 | vaini
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=vainivaini
# Processing record 49 | biak
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=biakbiak
# Processing record 50 | nome
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=nomenome
# Processing record 51 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=saskylakhsaskylakh
# Processing record 52 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=severo-kurilsksevero-kurilsk
# Processing record 53 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=punta arenaspunta arenas
# Processing record 54 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=ponta do solponta do sol
# Processing record 55 | northam
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=northamnortham
# Processing record 56 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=mar del platamar del plata
# Processing record 57 | avarua
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=avaruaavarua
# Processing record 58 | caravelas
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=caravelascaravelas
# Processing record 59 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=ushuaiaushuaia
# Processing record 60 | barrow
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=barrowbarrow
# Processing record 61 | tabou
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=taboutabou
# Processing record 62 | badiraguato
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=badiraguatobadiraguato
# Processing record 63 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=puerto ayorapuerto ayora
# Processing record 64 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=new norfolknew norfolk
# Processing record 65 | bunia
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=buniabunia
# City not found. Skipping......
# Processing record 66 | attawapiskat
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=attawapiskatattawapiskat
# Processing record 67 | sola
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=solasola
# Processing record 68 | mitsamiouli
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=mitsamioulimitsamiouli
# Processing record 69 | porbandar
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=porbandarporbandar
# Processing record 70 | hasaki
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=hasakihasaki
# Processing record 71 | valley city
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=valley cityvalley city
# Processing record 72 | koungheul
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=koungheulkoungheul
# Processing record 73 | cape town
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=cape towncape town
# Processing record 74 | fortuna
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=fortunafortuna
# Processing record 75 | hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=hermanushermanus
# Processing record 76 | samarai
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=samaraisamarai
# Processing record 77 | phan thiet
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=phan thietphan thiet
# Processing record 78 | isangel
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=isangelisangel
# Processing record 79 | istok
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=istokistok
# Processing record 80 | locri
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=locrilocri
# Processing record 81 | mingguang
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=mingguangmingguang
# Processing record 82 | imeni poliny osipenko
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=imeni poliny osipenkoimeni poliny osipenko
# Processing record 83 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=arraial do caboarraial do cabo
# Processing record 84 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=port elizabethport elizabeth
# City not found. Skipping......
# Processing record 85 | lolua
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=lolualolua
# Processing record 86 | ulaanbaatar
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=ulaanbaatarulaanbaatar
# Processing record 87 | bodo
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=bodobodo
# City not found. Skipping......
# Processing record 88 | suzu
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=suzusuzu
# Processing record 89 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=bathshebabathsheba
# Processing record 90 | buraydah
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=buraydahburaydah
# Processing record 91 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=kavarattikavaratti
# Processing record 92 | qianan
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=qiananqianan
# Processing record 93 | faridpur
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=faridpurfaridpur
# Processing record 94 | fairbanks
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=fairbanksfairbanks
# Processing record 95 | luderitz
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=luderitzluderitz
# Processing record 96 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=ilulissatilulissat
# Processing record 97 | marawi
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=marawimarawi
# Processing record 98 | henties bay
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=henties bayhenties bay
# Processing record 99 | saint-francois
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=saint-francoissaint-francois
# Processing record 100 | esperance
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=esperanceesperance
# Processing record 101 | tupiza
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=tupizatupiza
# Processing record 102 | lompoc
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=lompoclompoc
# Processing record 103 | portales
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=portalesportales
# Processing record 104 | la orilla
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=la orillala orilla
# Processing record 105 | mogadishu
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=mogadishumogadishu
# City not found. Skipping......
# Processing record 106 | zhanatas
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=zhanataszhanatas
# Processing record 107 | redmond
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=redmondredmond
# Processing record 108 | sioux lookout
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=sioux lookoutsioux lookout
# Processing record 109 | flinders
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=flindersflinders
# Processing record 110 | chicama
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=chicamachicama
# Processing record 111 | upernavik
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=upernavikupernavik
# Processing record 112 | aklavik
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=aklavikaklavik
# Processing record 113 | jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=jamestownjamestown
# Processing record 114 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=tuktoyaktuktuktoyaktuk
# Processing record 115 | kapuskasing
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=kapuskasingkapuskasing
# Processing record 116 | komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=komsomolskiykomsomolskiy
# City not found. Skipping......
# Processing record 117 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=taolanarotaolanaro
# Processing record 118 | mozhga
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=mozhgamozhga
# Processing record 119 | puerto baquerizo moreno
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=puerto baquerizo morenopuerto baquerizo moreno
# City not found. Skipping......
# Processing record 120 | rudbar
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=rudbarrudbar
# Processing record 121 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=yellowknifeyellowknife
# Processing record 122 | camacupa
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=camacupacamacupa
# Processing record 123 | margate
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=margatemargate
# Processing record 124 | lata
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=latalata
# Processing record 125 | xinxiang
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=xinxiangxinxiang
# Processing record 126 | egvekinot
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=egvekinotegvekinot
# Processing record 127 | chuy
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=chuychuy
# Processing record 128 | atherton
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=athertonatherton
# Processing record 129 | rio gallegos
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=rio gallegosrio gallegos
# Processing record 130 | vilyuysk
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=vilyuyskvilyuysk
# Processing record 131 | bembereke
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=bemberekebembereke
# Processing record 132 | alofi
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=alofialofi
# Processing record 133 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=bredasdorpbredasdorp
# Processing record 134 | itarema
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=itaremaitarema
# City not found. Skipping......
# Processing record 135 | disna
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=disnadisna
# Processing record 136 | cidreira
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=cidreiracidreira
# Processing record 137 | karratha
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=karrathakarratha
# Processing record 138 | narsaq
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=narsaqnarsaq
# Processing record 139 | kormend
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=kormendkormend
# Processing record 140 | nanakuli
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=nanakulinanakuli
# Processing record 141 | sisimiut
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=sisimiutsisimiut
# City not found. Skipping......
# Processing record 142 | barbar
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=barbarbarbar
# Processing record 143 | inhambane
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=inhambaneinhambane
# Processing record 144 | riyadh
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=riyadhriyadh
# Processing record 145 | wewak
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=wewakwewak
# City not found. Skipping......
# Processing record 146 | marcona
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=marconamarcona
# City not found. Skipping......
# Processing record 147 | amderma
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=amdermaamderma
# Processing record 148 | grindavik
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=grindavikgrindavik
# Processing record 149 | morondava
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=morondavamorondava
# Processing record 150 | haines junction
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=haines junctionhaines junction
# Processing record 151 | ambanja
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=ambanjaambanja
# Processing record 152 | peddapuram
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=peddapurampeddapuram
# Processing record 153 | siemiatycze
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=siemiatyczesiemiatycze
# Processing record 154 | maragogi
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=maragogimaragogi
# Processing record 155 | lasem
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=lasemlasem
# Processing record 156 | namibe
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=namibenamibe
# Processing record 157 | baghdad
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=baghdadbaghdad
# Processing record 158 | thompson
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=thompsonthompson
# City not found. Skipping......
# Processing record 159 | khomeynishahr
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=khomeynishahrkhomeynishahr
# Processing record 160 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=chokurdakhchokurdakh
# Processing record 161 | hambantota
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=hambantotahambantota
# City not found. Skipping......
# Processing record 162 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=nizhneyansknizhneyansk
# Processing record 163 | khatanga
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=khatangakhatanga
# Processing record 164 | chapais
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=chapaischapais
# Processing record 165 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=saint-philippesaint-philippe
# Processing record 166 | tilichiki
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=tilichikitilichiki
# Processing record 167 | revelstoke
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=revelstokerevelstoke
# Processing record 168 | faanui
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=faanuifaanui
# Processing record 169 | borovoy
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=borovoyborovoy
# City not found. Skipping......
# Processing record 170 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=belushya gubabelushya guba
# Processing record 171 | westport
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=westportwestport
# City not found. Skipping......
# Processing record 172 | svetlyy
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=svetlyysvetlyy
# Processing record 173 | te anau
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=te anaute anau
# Processing record 174 | tuy hoa
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=tuy hoatuy hoa
# Processing record 175 | vila velha
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=vila velhavila velha
# Processing record 176 | malanje
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=malanjemalanje
# City not found. Skipping......
# Processing record 177 | samusu
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=samususamusu
# Processing record 178 | pisco
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=piscopisco
# Processing record 179 | bambanglipuro
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=bambanglipurobambanglipuro
# Processing record 180 | yarada
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=yaradayarada
# Processing record 181 | banda aceh
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=banda acehbanda aceh
# Processing record 182 | tazmalt
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=tazmalttazmalt
# Processing record 183 | lavrentiya
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=lavrentiyalavrentiya
# Processing record 184 | saldanha
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=saldanhasaldanha
# City not found. Skipping......
# Processing record 185 | phu khieo
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=phu khieophu khieo
# Processing record 186 | corowa
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=corowacorowa
# Processing record 187 | georgetown
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=georgetowngeorgetown
# Processing record 188 | mwinilunga
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=mwinilungamwinilunga
# Processing record 189 | port blair
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=port blairport blair
# Processing record 190 | mabaruma
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=mabarumamabaruma
# Processing record 191 | batagay-alyta
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=batagay-alytabatagay-alyta
# Processing record 192 | challans
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=challanschallans
# Processing record 193 | quatre cocos
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=quatre cocosquatre cocos
# Processing record 194 | hofn
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=hofnhofn
# Processing record 195 | ekibastuz
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=ekibastuzekibastuz
# Processing record 196 | bagdarin
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=bagdarinbagdarin
# Processing record 197 | archidona
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=archidonaarchidona
# Processing record 198 | rolla
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=rollarolla
# Processing record 199 | raudeberg
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=raudebergraudeberg
# Processing record 200 | vostok
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=vostokvostok
# Processing record 201 | virginia beach
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=virginia beachvirginia beach
# Processing record 202 | kozhevnikovo
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=kozhevnikovokozhevnikovo
# Processing record 203 | yulara
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=yularayulara
# Processing record 204 | tura
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=turatura
# Processing record 205 | turbat
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=turbatturbat
# Processing record 206 | kindu
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=kindukindu
# City not found. Skipping......
# Processing record 207 | ngukurr
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=ngukurrngukurr
# Processing record 208 | whitehorse
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=whitehorsewhitehorse
# Processing record 209 | sarandi
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=sarandisarandi
# Processing record 210 | shelburne
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=shelburneshelburne
# Processing record 211 | prainha
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=prainhaprainha
# Processing record 212 | ponta delgada
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=ponta delgadaponta delgada
# Processing record 213 | katsuura
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=katsuurakatsuura
# Processing record 214 | cayenne
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=cayennecayenne
# Processing record 215 | akaltara
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=akaltaraakaltara
# Processing record 216 | preobrazheniye
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=preobrazheniyepreobrazheniye
# Processing record 217 | victoria
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=victoriavictoria
# Processing record 218 | visby
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=visbyvisby
# Processing record 219 | mount gambier
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=mount gambiermount gambier
# Processing record 220 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=nikolskoyenikolskoye
# Processing record 221 | rocha
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=rocharocha
# Processing record 222 | leshukonskoye
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=leshukonskoyeleshukonskoye
# Processing record 223 | bandar
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=bandarbandar
# Processing record 224 | trinidad
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=trinidadtrinidad
# Processing record 225 | saint george
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=saint georgesaint george
# Processing record 226 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=qaanaaqqaanaaq
# Processing record 227 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=iqaluitiqaluit
# Processing record 228 | rawson
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=rawsonrawson
# Processing record 229 | bud
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=budbud
# City not found. Skipping......
# Processing record 230 | karagaylinskiy
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=karagaylinskiykaragaylinskiy
# Processing record 231 | sarkand
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=sarkandsarkand
# Processing record 232 | tianpeng
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=tianpengtianpeng
# Processing record 233 | anloga
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=anlogaanloga
# Processing record 234 | alindao
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=alindaoalindao
# Processing record 235 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=cherskiycherskiy
# City not found. Skipping......
# Processing record 236 | sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=sentyabrskiysentyabrskiy
# Processing record 237 | monrovia
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=monroviamonrovia
# Processing record 238 | boende
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=boendeboende
# City not found. Skipping......
# Processing record 239 | vaitupu
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=vaitupuvaitupu
# Processing record 240 | lorengau
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=lorengaulorengau
# Processing record 241 | jinchang
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=jinchangjinchang
# Processing record 242 | saint-pierre
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=saint-pierresaint-pierre
# City not found. Skipping......
# Processing record 243 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=illoqqortoormiutilloqqortoormiut
# City not found. Skipping......
# Processing record 244 | tabiauea
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=tabiaueatabiauea
# Processing record 245 | valmiera
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=valmieravalmiera
# Processing record 246 | salinas
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=salinassalinas
# Processing record 247 | havelock
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=havelockhavelock
# Processing record 248 | kisangani
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=kisanganikisangani
# Processing record 249 | gold coast
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=gold coastgold coast
# Processing record 250 | husavik
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=husavikhusavik
# City not found. Skipping......
# Processing record 251 | grand river south east
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=grand river south eastgrand river south east
# Processing record 252 | mount isa
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=mount isamount isa
# Processing record 253 | guerrero negro
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=guerrero negroguerrero negro
# Processing record 254 | caceres
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=cacerescaceres
# Processing record 255 | vigeland
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=vigelandvigeland
# Processing record 256 | upington
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=upingtonupington
# City not found. Skipping......
# Processing record 257 | agva
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=agvaagva
# Processing record 258 | knysna
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=knysnaknysna
# Processing record 259 | ketchikan
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=ketchikanketchikan
# City not found. Skipping......
# Processing record 260 | kemijarvi
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=kemijarvikemijarvi
# Processing record 261 | kahului
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=kahuluikahului
# Processing record 262 | ixtapa
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=ixtapaixtapa
# Processing record 263 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=pangnirtungpangnirtung
# Processing record 264 | yahotyn
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=yahotynyahotyn
# Processing record 265 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=nanortaliknanortalik
# Processing record 266 | pochutla
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=pochutlapochutla
# Processing record 267 | roma
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=romaroma
# Processing record 268 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=kruisfonteinkruisfontein
# City not found. Skipping......
# Processing record 269 | sataua
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=satauasataua
# Processing record 270 | jaru
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=jarujaru
# Processing record 271 | avesta
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=avestaavesta
# Processing record 272 | ampanihy
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=ampanihyampanihy
# Processing record 273 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=tasiilaqtasiilaq
# Processing record 274 | qaqortoq
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=qaqortoqqaqortoq
# Processing record 275 | babu
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=babubabu
# Processing record 276 | takoradi
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=takoraditakoradi
# Processing record 277 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=vila franca do campovila franca do campo
# Processing record 278 | dunedin
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=dunedindunedin
# Processing record 279 | camacha
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=camachacamacha
# City not found. Skipping......
# Processing record 280 | olafsvik
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=olafsvikolafsvik
# Processing record 281 | los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=los llanos de aridanelos llanos de aridane
# Processing record 282 | mopti
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=moptimopti
# Processing record 283 | fort smith
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=fort smithfort smith
# Processing record 284 | honiara
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=honiarahoniara
# Processing record 285 | buta
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=butabuta
# Processing record 286 | aden
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=adenaden
# Processing record 287 | nova vicosa
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=nova vicosanova vicosa
# Processing record 288 | sinnamary
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=sinnamarysinnamary
# Processing record 289 | lazaro cardenas
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=lazaro cardenaslazaro cardenas
# Processing record 290 | sorland
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=sorlandsorland
# Processing record 291 | cam ranh
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=cam ranhcam ranh
# Processing record 292 | alghero
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=algheroalghero
# Processing record 293 | calbuco
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=calbucocalbuco
# Processing record 294 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=ribeira granderibeira grande
# Processing record 295 | three hills
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=three hillsthree hills
# City not found. Skipping......
# Processing record 296 | rungata
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=rungatarungata
# Processing record 297 | coihaique
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=coihaiquecoihaique
# Processing record 298 | plaridel
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=plaridelplaridel
# Processing record 299 | santa maria
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=santa mariasanta maria
# Processing record 300 | angoche
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=angocheangoche
# Processing record 301 | vao
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=vaovao
# Processing record 302 | muli
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=mulimuli
# Processing record 303 | geraldton
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=geraldtongeraldton
# Processing record 304 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=longyearbyenlongyearbyen
# Processing record 305 | gimli
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=gimligimli
# Processing record 306 | paris
# ...
# Processing record 488 | kendal
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=kendalkendal
# Processing record 489 | nova olimpia
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=nova olimpianova olimpia
# Processing record 490 | san juan
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=san juansan juan
# Processing record 491 | hamilton
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=hamiltonhamilton
# Processing record 492 | neiafu
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=neiafuneiafu
# Processing record 493 | natal
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=natalnatal
# Processing record 494 | tevaitoa
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=tevaitoatevaitoa
# Processing record 495 | alyangula
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=alyangulaalyangula
# Processing record 496 | thinadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=thinadhoothinadhoo
# Processing record 497 | starokozache
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=starokozachestarokozache
# Processing record 498 | inta
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=intainta
# City not found. Skipping......
# Processing record 499 | korla
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=korlakorla
# Processing record 500 | omsukchan
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=omsukchanomsukchan
# Processing record 501 | lebu
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=lebulebu
# Processing record 502 | xining
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=xiningxining
# Processing record 503 | garissa
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=garissagarissa
# Processing record 504 | isla mujeres
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=isla mujeresisla mujeres
# Processing record 505 | decin
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=decindecin
# City not found. Skipping......
# Processing record 506 | tawzar
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=tawzartawzar
# Processing record 507 | the valley
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=the valleythe valley
# Processing record 508 | key biscayne
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=key biscaynekey biscayne
# Processing record 509 | portland
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=portlandportland
# Processing record 510 | ambunti
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=ambuntiambunti
# Processing record 511 | kongoussi
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=kongoussikongoussi
# Processing record 512 | mezen
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=mezenmezen
# Processing record 513 | weligama
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=weligamaweligama
# Processing record 514 | yantai
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=yantaiyantai
# City not found. Skipping......
# Processing record 515 | zlatoustovsk
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=zlatoustovskzlatoustovsk
# Processing record 516 | armeria
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=armeriaarmeria
# City not found. Skipping......
# Processing record 517 | camana
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=camanacamana
# Processing record 518 | rio claro
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=rio clarorio claro
# Processing record 519 | moanda
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=moandamoanda
# Processing record 520 | novaya bryan
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=novaya bryannovaya bryan
# Processing record 521 | dan khun thot
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=dan khun thotdan khun thot
# City not found. Skipping......
# Processing record 522 | severnyy
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=severnyysevernyy
# Processing record 523 | greeley
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=greeleygreeley
# Processing record 524 | red bluff
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=red bluffred bluff
# Processing record 525 | lombardia
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=lombardialombardia
# Processing record 526 | paita
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=paitapaita
# Processing record 527 | kidal
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=kidalkidal
# Processing record 528 | port macquarie
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=port macquarieport macquarie
# Processing record 529 | pinar del rio
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=pinar del riopinar del rio
# Processing record 530 | oudtshoorn
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=oudtshoornoudtshoorn
# Processing record 531 | buguruslan
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=buguruslanbuguruslan
# Processing record 532 | san joaquin
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=san joaquinsan joaquin
# Processing record 533 | iracoubo
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=iracouboiracoubo
# City not found. Skipping......
# Processing record 534 | falealupo
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=falealupofalealupo
# Processing record 535 | atar
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=ataratar
# Processing record 536 | iki-burul
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=iki-buruliki-burul
# City not found. Skipping......
# Processing record 537 | pavda
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=pavdapavda
# Processing record 538 | sajanan
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=sajanansajanan
# Processing record 539 | tamiahua
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=tamiahuatamiahua
# Processing record 540 | marsa matruh
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=marsa matruhmarsa matruh
# Processing record 541 | nioki
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=niokinioki
# Processing record 542 | paoua
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=paouapaoua
# Processing record 543 | ust-kuyga
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=ust-kuygaust-kuyga
# Processing record 544 | kieta
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=kietakieta
# Processing record 545 | sao jose da coroa grande
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=sao jose da coroa grandesao jose da coroa grande
# Processing record 546 | goderich
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=goderichgoderich
# Processing record 547 | kumbo
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=kumbokumbo
# Processing record 548 | buala
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=bualabuala
# Processing record 549 | le port
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=le portle port
# Processing record 550 | tambacounda
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=tambacoundatambacounda
# Processing record 551 | puteyets
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=puteyetsputeyets
# City not found. Skipping......
# Processing record 552 | toliary
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=toliarytoliary
# Processing record 553 | sungaipenuh
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=sungaipenuhsungaipenuh
# Processing record 554 | akdagmadeni
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=akdagmadeniakdagmadeni
# Processing record 555 | dudinka
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=dudinkadudinka
# City not found. Skipping......
# Processing record 556 | kushmurun
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=kushmurunkushmurun
# Processing record 557 | goryachegorsk
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=goryachegorskgoryachegorsk
# Processing record 558 | kayes
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=kayeskayes
# Processing record 559 | lingao
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=lingaolingao
# Processing record 560 | taganak
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=taganaktaganak
# Processing record 561 | charleston
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=charlestoncharleston
# Processing record 562 | erenhot
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=erenhoterenhot
# Processing record 563 | bone
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=bonebone
# Processing record 564 | wahiawa
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=wahiawawahiawa
# Processing record 565 | gat
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=gatgat
# Processing record 566 | touros
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=tourostouros
# Processing record 567 | sur
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=sursur
# Processing record 568 | synya
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=synyasynya
# Processing record 569 | pevek
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=pevekpevek
# Processing record 570 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=sao filipesao filipe
# Processing record 571 | yamada
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=yamadayamada
# Processing record 572 | awbari
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=awbariawbari
# Processing record 573 | imbituba
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=imbitubaimbituba
# Processing record 574 | little current
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=little currentlittle current
# Processing record 575 | rio grande
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=rio granderio grande
# Processing record 576 | lasa
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=lasalasa
# Processing record 577 | poum
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=poumpoum
# Processing record 578 | ovsyanka
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=ovsyankaovsyanka
# Processing record 579 | artesia
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=artesiaartesia
# Processing record 580 | alta floresta
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=alta florestaalta floresta
# City not found. Skipping......
# Processing record 581 | mys shmidta
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=mys shmidtamys shmidta
# Processing record 582 | nahrin
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=nahrinnahrin
# Processing record 583 | tsaratanana
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=tsaratananatsaratanana
# Processing record 584 | mareeba
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=mareebamareeba
# Processing record 585 | gunjur
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=gunjurgunjur
# Processing record 586 | coolum beach
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=coolum beachcoolum beach
# Processing record 587 | meulaboh
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=meulabohmeulaboh
# Processing record 588 | zapolyarnyy
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=zapolyarnyyzapolyarnyy
# Processing record 589 | loralai
# http://api.openweathermap.org/data/2.5/weather?appid=3a0a0fa80d8c1600856bc8b7862dd174&units=imperial&q=loralailoralai

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a dictionary from the weather data lists. Used to create dataframe
# create a data frame from openweathermap response

weather_dict = {
    'City': city_name,
    'City ID': city_id,
    'Latitude': lat,
    'Max Temp': max_temp,
    'Humidity': humid,
    'Wind Speed': wind,
    '% Clouds': clouds,
    'Date': time.strftime('%m/%d/%y')  
}
weather_dict

weather_df = pd.DataFrame(weather_dict)
weather_df.to_csv('weather_data.csv')
weather_df.head()
# Out:
#       City  City ID  Latitude  Max Temp  Humidity  Wind Speed  % Clouds  \
# 0    Ancud  3899695    -41.87     59.00        62        8.05        20
# 1  Atambua  1651103     -9.11     78.59       100        2.62        88
# 2   Hobart  2163355    -42.88     64.40        77        1.12        75
# 3   Albany  5106834     42.65     33.98        47       24.16        75
# 4  Rikitea  4030556    -23.12     80.61        99       10.00        56
#
#        Date
# 0  01/16/19
# 1  01/16/19
# 2  01/16/19
# 3  01/16/19
# 4  01/16/19

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Create the scatter plot for latitude v temp using the weather_df dataframe
current_date = time.strftime('%m/%d/%y')

plt.scatter(weather_df['Latitude'], weather_df['Max Temp'], c='blue', edgecolors='black', alpha=.75)

# Incorporate the other graph properties
current_date = time.strftime('%m/%d/%y')
plt.title(f'City Latitude vs. Maximum Temperature {current_date}')
plt.xlabel("Latitude")
plt.ylabel("Max Temp (℉)")
plt.grid()
plt.savefig('Lat v Temp.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Create the scatter plot for humidity v temp.
plt.scatter(weather_df['Latitude'], weather_df['Humidity'], c='blue', edgecolors='black', alpha=.75)

# Incorporate the other graph properties
current_date = time.strftime('%m/%d/%y')
plt.title(f'City Latitude vs. Humidity {current_date}')
plt.xlabel("Latitude")
plt.ylabel("Humididty %")
plt.grid()
plt.savefig('Lat v Humid.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Create the scatter plot for clouds v temp.
plt.scatter(weather_df['Latitude'], weather_df['% Clouds'], c='blue', edgecolors='black', alpha=.75)

# Incorporate the other graph properties
current_date = time.strftime('%m/%d/%y')
plt.title(f'City Latitude vs. Coudiness {current_date}')
plt.xlabel("Latitude")
plt.ylabel("Cloudiness %")
plt.grid()
plt.savefig('Lat v Cloud.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Create the scatter plot for wind v temp.
plt.scatter(weather_df['Latitude'], weather_df['Wind Speed'], c='blue', edgecolors='black', alpha=.75)

# Incorporate the other graph properties
current_date = time.strftime('%m/%d/%y')
plt.title(f'City Latitude vs. Coudiness {current_date}')
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
plt.savefig('Lat v Wind.png')
plt.show()
